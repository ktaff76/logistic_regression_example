# %%
import mord as m
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from mord import LogisticIT
from dmba import classificationSummary, gainsChart, liftChart
from dmba.metric import AIC_score
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
# %matplotlib inline

# %%
#Data Set
EmpAttr_df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition_logisticregression.csv')

# %%
x=EmpAttr_df.drop(columns=['Attrition'])
y=EmpAttr_df['Attrition']

train_x, valid_x, train_y, valid_y = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
model = LogisticRegression()
model.fit(train_x, train_y)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(valid_x)

# %%
accuracy = accuracy_score(valid_y, y_pred)
conf_matrix = confusion_matrix(valid_y, y_pred)
class_report = classification_report(valid_y, y_pred)

print(f'Accuracy: {accuracy}')
print('Confusion Matrix:')
print(conf_matrix)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 0.8673469387755102
# Confusion Matrix:
# [[255   0]
#  [ 39   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#           No       0.87      1.00      0.93       255
#          Yes       0.00      0.00      0.00        39
#
#     accuracy                           0.87       294
#    macro avg       0.43      0.50      0.46       294
# weighted avg       0.75      0.87      0.81       294
# C:\Users\ktaff706\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
logit_reg = LogisticRegression(penalty='l2', C = 1e42, solver='liblinear')
logit_reg.fit(train_x, train_y)

print('intercept', logit_reg.intercept_[0])
print(pd.DataFrame({'coeff':logit_reg.coef_[0]}, index=x.columns).transpose())
# Out:
# intercept -0.0012092513231944397
#             Age  DailyRate  DistanceFromHome  HourlyRate  MonthlyIncome  \
# coeff -0.025505  -0.000296          0.021088   -0.001103       -0.00007
#
#        MonthlyRate  TotalWorkingYears
# coeff     0.000004          -0.026348
